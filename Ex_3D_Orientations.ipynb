# %% [markdown]
# ## Generic equations
#
# $$ T(R, \boldsymbol{t}) = \begin{bmatrix}R & \pmb{t} \\ \pmb{0}^T & 1 \end{bmatrix} $$
#
# $$ T(R, \boldsymbol{t})^{-1} = \begin{bmatrix} R^T & -R^T \pmb{t} \\ \pmb{0}^T & 1\end{bmatrix}  $$

# %%
# Helper functions

def createR3D(theta):
    return np.array([[np.cos(theta), -np.sin(theta)],[np.sin(theta),np.cos(theta)]])

def createT3D(theta,t):
    assert (t.shape == (2,)),"Incorrect translation size"
    T = np.eye(3)
    T[:2,:2] = createR2D(theta)
    T[:2,2] = t
    return T

def createTinv3D(T):
    assert (T.shape == (3,3)),"Incorrect size"
    Tinv = np.empty_like(T)
    np.copyto(Tinv,T)
    Tinv[:2,:2] = T[:2,:2].T
    Tinv[:2,2] = (-T[:2,:2].T).dot(T[:2,2])
    return Tinva

def qRot(q,v):
    
def qMult(q1,q2):
    
def qInv

# %% [markdown]
# ----

# %% [markdown]
# ### 1 Rotation only in 3D
#
# a) A vector is given by $\pmb{p}^a = [4, 3, 2]^T$. Calculate $\pmb{p}^b$, given $q^{ba} = [0, 0, 0, 1]^T$.

# %%
#

# %% [markdown]
# b) A vector is given by $\pmb{p}^a = [4, 3, 2]^T$. Calculate $\pmb{p}^b$, given $q^{ba} = [0.40515, 0.45748, -0.77758, -0.14809]^T$ and $\pmb{t}_a^b = [2, 3, 1]^T$.

# %%
#

# %% [markdown]
# ### 2 Motion and time

# %% [markdown]
# The current velocity of a car is $50 km/h$, it starts to accelerate with $3 m/s^2$. Calculate the position difference after $10~s$

# %%
#
# Out:
# 288.8888888888889
